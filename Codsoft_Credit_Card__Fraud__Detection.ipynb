# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanashripalde13/Codsoft-internship/blob/main/Codsoft_Credit_Card__Fraud__Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import svm

# %%
train_df=pd.read_csv("fraudTrain.csv")
train_df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
test_df=pd.read_csv("fraudTest.csv")
test_df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
combined_df=pd.concat([train_df, test_df], ignore_index=True)
data=combined_df

# %%
data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
data.tail()
# Out:
#        Unnamed: 0 trans_date_trans_time               cc_num  \
# 15608        7793   2020-06-23 13:01:43      377113842678100
# 15609        7794   2020-06-23 13:02:09     6538891242532018
# 15610        7795   2020-06-23 13:02:35        4658117080136
# 15611        7796   2020-06-23 13:03:43     2720830304681674
# 15612        7797   2020-06-23 13:03:50  4992346398065154184
#
#                            merchant        category     amt     first  \
# 15608        fraud_Fritsch and Sons  health_fitness  152.25     Billy
# 15609  fraud_Torp, Muller and Borer  health_fitness   32.66      Jodi
# 15610             fraud_Haley Group        misc_pos    8.50    Dwayne
# 15611           fraud_Kozey-Kuhlman   personal_care   20.09   Melissa
# 15612             fraud_Yost-Rogahn   personal_care   74.00  Benjamin
#
#             last gender                          street  ...      lat  \
# 15608  Gallagher      M                673 Delgado Burg  ...  39.4055
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15613 entries, 0 to 15612
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             15613 non-null  int64
#  1   trans_date_trans_time  15613 non-null  object
#  2   cc_num                 15613 non-null  int64
#  3   merchant               15613 non-null  object
#  4   category               15613 non-null  object
#  5   amt                    15613 non-null  float64
#  6   first                  15613 non-null  object
#  7   last                   15613 non-null  object
#  8   gender                 15612 non-null  object
#  9   street                 15612 non-null  object
#  10  city                   15612 non-null  object
#  11  state                  15612 non-null  object
#  12  zip                    15612 non-null  float64
#  13  lat                    15612 non-null  float64
# ...

# %%
data.shape
# Out:
# (15613, 23)

# %%
data.describe()
# Out:
#          Unnamed: 0        cc_num           amt           zip           lat  \
# count  15613.000000  1.561300e+04  15613.000000  15612.000000  15612.000000
# mean    3902.754628  4.061600e+17     68.659763  48974.185242     38.541164
# std     2253.622607  1.294140e+18    118.841586  26980.057752      5.143933
# min        0.000000  6.041621e+10      1.000000   1257.000000     20.027100
# 25%     1951.000000  1.800365e+14      9.610000  26041.000000     34.699875
# 50%     3903.000000  3.518669e+15     47.500000  48202.000000     39.362950
# 75%     5854.000000  4.651007e+15     81.940000  72047.000000     41.940400
# max     7814.000000  4.992346e+18   3204.980000  99783.000000     65.689900
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  15612.000000  1.561200e+04  1.561100e+04  15611.000000  15611.000000
# mean     -90.332979  9.328824e+04  1.348718e+09     38.533519    -90.331203
# ...

# %%
len(data)
# Out:
# 15613

# %%
data['is_fraud'].value_counts()
# Out:
# 0.0    15544
# 1.0       67
# Name: is_fraud, dtype: int64

# %%
good = data [data.is_fraud == 0]
fraud = data [data.is_fraud == 1]

# %%
fraud
# Out:
#        Unnamed: 0 trans_date_trans_time            cc_num  \
# 2449         2449   2019-01-02 01:06:37     4613314721966
# 2472         2472   2019-01-02 01:47:29   340187018810220
# 2523         2523   2019-01-02 03:05:23   340187018810220
# 2546         2546   2019-01-02 03:38:03     4613314721966
# 2553         2553   2019-01-02 03:55:47   340187018810220
# ...           ...                   ...               ...
# 10465        2650   2020-06-22 04:58:25  3524574586339330
# 13484        5669   2020-06-22 21:51:05  4005676619255478
# 13572        5757   2020-06-22 22:20:13  3524574586339330
# 13755        5940   2020-06-22 23:08:25  3524574586339330
# 13838        6023   2020-06-22 23:35:47  3524574586339330
#
#                                   merchant        category     amt    first  \
# 2449                fraud_Rutherford-Mertz     grocery_pos  281.06    Jason
# 2472      fraud_Jenkins, Hauck and Friesen   gas_transport   11.52    Misty
# ...

# %%
good.shape
# Out:
# (15544, 23)

# %%
good.amt.describe()
# Out:
# count    15544.000000
# mean        66.605722
# std        111.950154
# min          1.000000
# 25%          9.580000
# 50%         47.340000
# 75%         81.590000
# max       3204.980000
# Name: amt, dtype: float64

# %%
fraud.amt.describe()
# Out:
# count      67.000000
# mean      545.172388
# std       397.272820
# min         4.500000
# 25%       262.205000
# 50%       701.810000
# 75%       858.985000
# max      1254.270000
# Name: amt, dtype: float64

# %%
good_sample = good.sample(n=25)

# %%
new_data = pd.concat([good_sample,fraud],axis=0)

# %%
new_data.tail()
# Out:
#        Unnamed: 0 trans_date_trans_time            cc_num  \
# 10465        2650   2020-06-22 04:58:25  3524574586339330
# 13484        5669   2020-06-22 21:51:05  4005676619255478
# 13572        5757   2020-06-22 22:20:13  3524574586339330
# 13755        5940   2020-06-22 23:08:25  3524574586339330
# 13838        6023   2020-06-22 23:35:47  3524574586339330
#
#                                   merchant        category     amt    first  \
# 10465                     fraud_Schumm PLC    shopping_net  967.86   Ashley
# 13484  fraud_Baumbach, Strosin and Nicolas    shopping_pos  825.81  William
# 13572                fraud_Shanahan-Lehner   personal_care   21.92   Ashley
# 13755           fraud_Haley, Batz and Auer  health_fitness   21.74   Ashley
# 13838                fraud_Kutch-Wilderman            home  250.32   Ashley
#
#           last gender                        street  ...     lat     long  \
# 10465  Cabrera      F  94225 Smith Springs Apt. 617  ...  27.633 -80.4031
# ...

# %%
x1 = new_data.drop('is_fraud',axis = 1)

# %%
y1 = new_data['is_fraud']

# %%
y1
# Out:
# 1993     0.0
# 2713     0.0
# 13313    0.0
# 4103     0.0
# 1224     0.0
#         ...
# 10465    1.0
# 13484    1.0
# 13572    1.0
# 13755    1.0
# 13838    1.0
# Name: is_fraud, Length: 92, dtype: float64

# %%
x1
# Out:
#        Unnamed: 0 trans_date_trans_time            cc_num  \
# 1993         1993   2019-01-01 20:33:51  3518669219150142
# 2713         2713   2019-01-02 08:17:47  4450831335606294
# 13313        5498   2020-06-22 21:02:19  4424338559877976
# 4103         4103   2019-01-03 13:31:55  3596217206093829
# 1224         1224   2019-01-01 14:31:02     4189814094741
# ...           ...                   ...               ...
# 10465        2650   2020-06-22 04:58:25  3524574586339330
# 13484        5669   2020-06-22 21:51:05  4005676619255478
# 13572        5757   2020-06-22 22:20:13  3524574586339330
# 13755        5940   2020-06-22 23:08:25  3524574586339330
# 13838        6023   2020-06-22 23:35:47  3524574586339330
#
#                                   merchant        category     amt    first  \
# 1993           fraud_Metz, Russel and Metz       kids_pets  305.12  Dorothy
# 2713                  fraud_Corwin-Collins   gas_transport   36.82    Donna
# ...

# %%
x1 = x1.apply(pd.to_numeric, errors='coerce')
y1 = y1.apply(pd.to_numeric, errors='coerce')

# %%
x1.fillna(0, inplace=True)
y1.fillna(0, inplace=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(x1,y1,test_size=0.25,random_state=0)

# %%
print(X_train)
# Out:
#        Unnamed: 0  trans_date_trans_time            cc_num  merchant  \
# 4744         4744                    0.0   340187018810220       0.0
# 9771         1956                    0.0  4005676619255478       0.0
# 9672         1857                    0.0  3560725013359375       0.0
# 6240         6240                    0.0   341546199006537       0.0
# 9706         1891                    0.0  3524574586339330       0.0
# ...           ...                    ...               ...       ...
# 13484        5669                    0.0  4005676619255478       0.0
# 7559         7559                    0.0   341546199006537       0.0
# 7529         7529                    0.0   341546199006537       0.0
# 5559         5559                    0.0   341546199006537       0.0
# 4808         4808                    0.0   341546199006537       0.0
#
#        category     amt  first  last  gender  street  ...      zip      lat  \
# ...

# %%
print(y_train)
# Out:
# 4744     1.0
# 9771     1.0
# 9672     1.0
# 6240     1.0
# 9706     1.0
#         ...
# 13484    1.0
# 7559     1.0
# 7529     1.0
# 5559     1.0
# 4808     1.0
# Name: is_fraud, Length: 69, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()

# %%
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
x1_prediction = log.predict(X_train)

# %%
x1_accuracy = accuracy_score(x1_prediction,y_train)

# %%
x1_accuracy
# Out:
# 0.7536231884057971

# %%
y1_predict = log.predict(X_test)

# %%
y1_accuracy = accuracy_score(y1_predict,y_test)

# %%
y1_accuracy
# Out:
# 0.6521739130434783

# %%
from sklearn.metrics import precision_score,recall_score,f1_score
x1_precision = precision_score(x1_prediction,y_train)

# %%
x1_precision
# Out:
# 1.0

# %%
y1_precision = precision_score(y1_predict,y_test)

# %%
y1_precision
# Out:
# 1.0

# %%
x1_recall = recall_score(x1_prediction,y_train)

# %%
x1_recall
# Out:
# 0.7536231884057971

# %%
y1_recall = recall_score(y1_predict,y_test)

# %%
y1_recall
# Out:
# 0.6521739130434783

# %%
x1_f1 = f1_score(x1_prediction,y_train)

# %%
x1_f1
# Out:
# 0.859504132231405

# %%
y1_f1 = f1_score(y1_predict,y_test)

# %%
y1_f1
# Out:
# 0.7894736842105263
